# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#                name         diet                                      period
# 0       abelisaurus  carnivorous     Late Cretaceous 74-70 million years ago  \
# 1          aardonyx  herbivorous    Early Jurassic 199-189 million years ago
# 2      achillobator  carnivorous     Late Cretaceous 99-84 million years ago
# 3     achelousaurus  herbivorous     Late Cretaceous 83-70 million years ago
# 4  acrocanthosaurus  carnivorous  Early Cretaceous 115-105 million years ago
#
#        lived_in            type length
# 0     Argentina  large theropod   9.0m  \
# 1  South Africa        sauropod   8.0m
# 2      Mongolia  large theropod   5.0m
# 3           USA     ceratopsian   6.0m
# 4           USA  large theropod  12.0m
#
#                                             taxonomy
# 0  Dinosauria Saurischia Theropoda Neotheropoda C...  \
# 1  Dinosauria Saurischia Sauropodomorpha Prosauro...
# 2  Dinosauria Saurischia Theropoda Neotheropoda T...
# 3  Dinosauria Ornithischia Genasauria Cerapoda Ma...
# 4  Dinosauria Saurischia Theropoda Neotheropoda T...
#
#                                             named_by      species
# 0                         Bonaparte and Novas (1985)  comahuensis  \
# 1  Yates Bonnan Neveling Chinsamy and Blackbeard ...     celestae
# 2                      Perle Norell and Clark (1999)    giganteus
# 3                                    Sampson  (1995)      horneri
# 4                        Stovall and Langston (1950)    atokensis
#
#                                                 link
# 0  https://www.nhm.ac.uk/discover/dino-directory/...  \
# 1  https://www.nhm.ac.uk/discover/dino-directory/...
# 2  https://www.nhm.ac.uk/discover/dino-directory/...
# 3  https://www.nhm.ac.uk/discover/dino-directory/...
# 4  https://www.nhm.ac.uk/discover/dino-directory/...
#
#                                                image
# 0  https://www.nhm.ac.uk/resources/nature-online/...  \
# 1   http://www.rareresource.com/images/aardonyx-d...
# 2  https://www.nhm.ac.uk/resources/nature-online/...
# 3  https://www.nhm.ac.uk/resources/nature-online/...
# 4  https://www.nhm.ac.uk/resources/nature-online/...
#
#                                          coordinates   latitude   longitude
# 0                                          Argentina -34.996496  -64.967282
# 1                                       South Africa -28.816624   24.991639
# 2  Mongolia, Markham, Whitchurch-Stouffville, Yor...  43.938259  -79.223556
# 3                                      United States  39.783730 -100.445882
# 4                                      United States  39.783730 -100.445882

# %%
df.isnull().sum()
# Out:
# name            0
# diet            0
# period          0
# lived_in        0
# type            0
# length         18
# taxonomy        0
# named_by        0
# species         5
# link            0
# image           1
# coordinates     0
# latitude        0
# longitude       0
# dtype: int64

# %%
df.dropna(axis=0, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df[df.diet=='herbivorous/omnivorous']
# Out:
#             name                    diet
# 222  riojasaurus  herbivorous/omnivorous  \
#
#                                       period   lived_in      type length
# 222  Late Triassic 221-210 million years ago  Argentina  sauropod  5.15m  \
#
#                                               taxonomy          named_by
# 222  Dinosauria Saurischia Sauropodomorpha Prosauro...  Bonaparte (1969)  \
#
#       species                                               link
# 222  incertus  https://www.nhm.ac.uk/discover/dino-directory/...  \
#
#                                                  image coordinates   latitude
# 222  https://www.nhm.ac.uk/resources/nature-online/...   Argentina -34.996496  \
#
#      longitude
# 222 -64.967282

# %%
df.at[222, 'diet'] = 'herbivorous'

# %%
df[df.lived_in=='unknown']
# Out:
#           name        diet period lived_in            type length
# 116  hagryphus  omnivorous    USA  unknown  small theropod   3.0m  \
#
#                                               taxonomy
# 116  Dinosauria Saurischia Theropoda Neotheropoda T...  \
#
#                      named_by    species
# 116  Zanno and Sampson (2005)  giganteus  \
#
#                                                   link
# 116  https://www.nhm.ac.uk/discover/dino-directory/...  \
#
#                                                  image
# 116  https://www.nhm.ac.uk/resources/nature-online/...  \
#
#                                            coordinates   latitude  longitude
# 116  Unknown, Citycenter Tahsil, Gwalior District, ...  26.166865  78.177826

# %%
df.drop(116, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.length = list(map(lambda x: float(x[:-1]), df.length))

# %%
def process_period(period):
    period_name = ''
    for c in range(len(period)):
        if period[c].isdigit():
            break
        else:
            period_name += period[c]
    period_name = period_name.strip()
    return period_name

# %%
df['modified_period'] = list(map(lambda x: process_period(x), df.period))

# %%
cols_to_capitalize = ['name', 'diet', 'type', 'species']

# %%
for each in cols_to_capitalize:
    df[each] = list(map(lambda x: x.title(), df[each]))

# %%
df.head()
# Out:
#                name         diet                                      period
# 0       Abelisaurus  Carnivorous     Late Cretaceous 74-70 million years ago  \
# 1          Aardonyx  Herbivorous    Early Jurassic 199-189 million years ago
# 2      Achillobator  Carnivorous     Late Cretaceous 99-84 million years ago
# 3     Achelousaurus  Herbivorous     Late Cretaceous 83-70 million years ago
# 4  Acrocanthosaurus  Carnivorous  Early Cretaceous 115-105 million years ago
#
#        lived_in            type  length
# 0     Argentina  Large Theropod     9.0  \
# 1  South Africa        Sauropod     8.0
# 2      Mongolia  Large Theropod     5.0
# 3           USA     Ceratopsian     6.0
# 4           USA  Large Theropod    12.0
#
#                                             taxonomy
# 0  Dinosauria Saurischia Theropoda Neotheropoda C...  \
# 1  Dinosauria Saurischia Sauropodomorpha Prosauro...
# 2  Dinosauria Saurischia Theropoda Neotheropoda T...
# 3  Dinosauria Ornithischia Genasauria Cerapoda Ma...
# 4  Dinosauria Saurischia Theropoda Neotheropoda T...
#
#                                             named_by      species
# 0                         Bonaparte and Novas (1985)  Comahuensis  \
# 1  Yates Bonnan Neveling Chinsamy and Blackbeard ...     Celestae
# 2                      Perle Norell and Clark (1999)    Giganteus
# 3                                    Sampson  (1995)      Horneri
# 4                        Stovall and Langston (1950)    Atokensis
#
#                                                 link
# 0  https://www.nhm.ac.uk/discover/dino-directory/...  \
# 1  https://www.nhm.ac.uk/discover/dino-directory/...
# 2  https://www.nhm.ac.uk/discover/dino-directory/...
# 3  https://www.nhm.ac.uk/discover/dino-directory/...
# 4  https://www.nhm.ac.uk/discover/dino-directory/...
#
#                                                image
# 0  https://www.nhm.ac.uk/resources/nature-online/...  \
# 1   http://www.rareresource.com/images/aardonyx-d...
# 2  https://www.nhm.ac.uk/resources/nature-online/...
# 3  https://www.nhm.ac.uk/resources/nature-online/...
# 4  https://www.nhm.ac.uk/resources/nature-online/...
#
#                                          coordinates   latitude   longitude
# 0                                          Argentina -34.996496  -64.967282  \
# 1                                       South Africa -28.816624   24.991639
# 2  Mongolia, Markham, Whitchurch-Stouffville, Yor...  43.938259  -79.223556
# 3                                      United States  39.783730 -100.445882
# 4                                      United States  39.783730 -100.445882
#
#     modified_period
# 0   Late Cretaceous
# 1    Early Jurassic
# 2   Late Cretaceous
# 3   Late Cretaceous
# 4  Early Cretaceous

# %%
df.to_csv('data_preprocessed.csv', index=False)
